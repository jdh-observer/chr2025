# %% [markdown]
# # Introduction and Workshop Scope : "RDF Dump"
#
# The workshop offers a playground notebook to create or to explore RDF dumps. If you are unfamiliar with linked data, we recommend reading the [corresponding lesson of "Programming Historian"](https://doi.org/10.46430/phen0068).
#
# This workshop offers a brief practical introduction of how to browse RDF dumps or how to build RDF graphs for database exploration and open research purposes. Basic know-how about querying or building LOD data, basic analysis for exploration, here in the Python language, and editorial issues should be in the hands of trainees.
#
# This workshop is split in five parts, plus further reading:
# 1. A first part introduces Python packages to be used in Jupyter notebooks. Some ressource gives further tutorials for working on your local machine.
# 2. A second part provides Python recipies for browsing dumps from wikidata and Factgrid wikibase, in order to collect data from the graph.
# 3. A third part helps with building RDF graphs in Python using `rdflib`.
# 4. A fourth part shows how to use of SPARQL queries and how to display results on maps or timelines, leading to first concrete examples.
# 5. A last part aims at producing a scientific publication within the Journal of Digital History's editorial technology stack.
#
# # General framework: from data to scientific publication
#
# ## From data collection
#
# Data in the scope of the workshop are linked open data available on FactGrid, a database for historical research. It is an international collaborative platform using Wikimedia's ground-breaking wikibase software, run at the Gotha Research Centre and hosted at the Thuringian State and University Library ThULB in Jena (see https://blog.factgrid.de/welcome).

# %%
from IPython.display import IFrame
IFrame('https://blog.factgrid.de/', width='100%', height='422')
# Out:
#         <iframe
#             width="100%"
#             height="422"
#             src="https://blog.factgrid.de/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## Data model under scope
#
# These data follow a general modelling framework for RDF triplets with domains and ranges that can take many value types (statements, xsd date, simple values etc.), like in a wikidata dump. Predicates also follow the wikidata schema with differentiating paths regarding the type of property under scope (see for exemple, figure below).

# %%
from IPython.display import Image, display
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": ["Wikidata model, source : [https://www.mediawiki.org/wiki/Wikibase/Indexing/RDF_Dump_Format](https://www.mediawiki.org/wiki/Wikibase/Indexing/RDF_Dump_Format)"]
        }
    }
}
display(Image("./img/Rdf_mapping-vector.svg.png"),metadata=metadata)

# %% [markdown]
# ## Computational notebook framework: multi-purpose from exploration to scientific publication, through workshop training
#
# Within this workshop, you will be invited to play with your own computational Jupyter notebook online. However, the more curious or skilled may follow our guidelines (in French) to install local Jupyter instances for running the workshop's computational notebooks directly on your own machine: [Ressources to install Jupyter Notebook framework on your local machine](https://mise-en-pratique-5e5223.gricad-pages.univ-grenoble-alpes.fr/jupyter.html).
#
# The Jupyter notebook may take two different forms: one based on mystmd technology, and the traditional JSON format ipynb. If you wish to prepare a JDH article proposal with the framework proposed, you may follow these two steps:
# - push your ipynb into a github repo,
# - copy-paste the URL of your ipynb computational notebook on your github repo there: [View JDH](https://journalofdigitalhistory.org/en/notebook-viewer-form)

# %%
from IPython.display import Image, display
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": ["Narrative, hermeneutical and code layers of the Journal of Digital History, image captured from the JDH article [https://doi.org/10.1515/JDH-2023-0018](https://doi.org/10.1515/JDH-2023-0018)"]
        }
    }
}
display(Image("./img/jdh.png"),metadata=metadata)

# %% [markdown]
# # Technologies to compute: Python libraries to perform SPARQL queries
#
# For this workshop, we chose the Python language and librairies for SPARQL queries and data visualization.
#
# ## Python packages used
#
# - `rdflib`: working with RDF data and making SPARQL queries
# - `networkx`: managing graphs
# - `matplotlib`: plotting
# - `plotly`: plotting as well
# - `pandas`: dataframes (tabular data) in Python
# - `geopandas`: an extension of `pandas` for spatial objects
# - `ipysigma`: for display interactives graphs
#
# ## A "reproducible" process ?
#
# Another package is used here to give information about how we produced the computational document. Notably, the package `session_info` gives information about system and package versions, enabling reproducibility in a controlled computational environment.
#
# - `session_info` : retrieve software version numbers
#
# ## Install packages
#
# In your terminal or inside your notebook, you can install these packages with `pip`:
#
# ```{code} python
# !pip install session_info rdflib networkx matplotlib plotly pandas ipysigma
# ```
#
# # Ontologies, namespaces or vocabularies: before browsing FactGrid wikibase dump
#
# As stated in programming historian's lesson, building knowledge graphs require some vocabularies, like w3c standards. These namespaces are url were classes or concepts may be found within their hierarchical relations or inherited relations or equivalence (sameAs), for example. SPARQL syntax usually shorten these namespaces with associated prefixes, stated at the head of the SPARQL query.
#
# ## Namespaces and prefixes
#
# Many widely used namespaces are predefined in `rdflib`, e.g. `FOAF`, `DublinCore`, `Schema`, or `XSD`.
# Many widely used namespaces are predefined in `rdflib` package, e.g. `FOAF`, `DublinCore`, `Schema`, or `XSD`. To have a complete overview of namespaces directly available within the proposed `rdflin` framework, the following steps are useful :

# %%
from rdflib import Graph, Namespace
# rdflib knows about quite a few popular namespaces, like W3C ontologies, schema.org etc.
#from rdflib.namespace import FOAF , XSD

# Create a Graph
g = Graph()


for prefix,ns in g.namespaces():
   print(f"""{prefix}: {ns}""")
# Out:
# brick: https://brickschema.org/schema/Brick#
# csvw: http://www.w3.org/ns/csvw#
# dc: http://purl.org/dc/elements/1.1/
# dcat: http://www.w3.org/ns/dcat#
# dcmitype: http://purl.org/dc/dcmitype/
# dcterms: http://purl.org/dc/terms/
# dcam: http://purl.org/dc/dcam/
# doap: http://usefulinc.com/ns/doap#
# foaf: http://xmlns.com/foaf/0.1/
# geo: http://www.opengis.net/ont/geosparql#
# odrl: http://www.w3.org/ns/odrl/2/
# org: http://www.w3.org/ns/org#
# prof: http://www.w3.org/ns/dx/prof/
# prov: http://www.w3.org/ns/prov#
# qb: http://purl.org/linked-data/cube#
# schema: https://schema.org/
# sh: http://www.w3.org/ns/shacl#
# skos: http://www.w3.org/2004/02/skos/core#
# sosa: http://www.w3.org/ns/sosa/
# ssn: http://www.w3.org/ns/ssn/
# time: http://www.w3.org/2006/time#
# vann: http://purl.org/vocab/vann/
# void: http://rdfs.org/ns/void#
# wgs: https://www.w3.org/2003/01/geo/wgs84_pos#
# owl: http://www.w3.org/2002/07/owl#
# rdf: http://www.w3.org/1999/02/22-rdf-syntax-ns#
# rdfs: http://www.w3.org/2000/01/rdf-schema#
# xsd: http://www.w3.org/2001/XMLSchema#
# xml: http://www.w3.org/XML/1998/namespace

# %% [markdown]
# However, we see no `wikibase`, nor `wikidata` or `dbpedia` namespaces. These have to be declared and bounded to specific prefixes.
#
# ## Querying Wikidata

# %%
# import Graph & Namespace

from rdflib import Graph, Namespace
from rdflib.namespace import NamespaceManager

# Wikidata namespace
WD = Namespace("http://www.wikidata.org/entity/")

# define graph to be crawled in
g2 = Graph()
g2.bind("wd", WD)

# define query about Mona Lisa QID
qres = g2.query(
  """
  SELECT ?o
  WHERE {
    SERVICE <https://query.wikidata.org/sparql> {
      wd:Q12418 rdfs:label ?o .
    }
  }
  LIMIT 10
  """
)

# %%
# print results nicely
for row in qres:
   print("wikidata identifier Q12418 <has label> : %s" %row)
# Out:
# wikidata identifier Q12418 <has label> : Mona Lisa
# wikidata identifier Q12418 <has label> : La Joconde
# wikidata identifier Q12418 <has label> : موناليزا
# wikidata identifier Q12418 <has label> : Мона Лиза
# wikidata identifier Q12418 <has label> : 모나리자
# wikidata identifier Q12418 <has label> : موناليزا
# wikidata identifier Q12418 <has label> : Mona Lisa
# wikidata identifier Q12418 <has label> : ሞና ሊዛ
# wikidata identifier Q12418 <has label> : A Gioconda
# wikidata identifier Q12418 <has label> : মনালিছা

# %% [markdown]
# # Querying FactGrid
#
# ## 1.0 - Collecting keywords

# %%
# test with Factgrid namespace
FG_WD = Namespace("https://database.factgrid.de/entity/")
FG_WDT = Namespace("https://database.factgrid.de/prop/direct/")

# define graph to be crawled in
g3 = Graph()
g3.bind("fg_wd", FG_WD)
g3.bind("fg_wdt", FG_WDT)

# define query for keywords
qres = g3.query(
"""
SELECT DISTINCT ?p (COALESCE(?p_labell,'') AS ?p_label)
WHERE {
  SERVICE <https://database.factgrid.de/sparql> {
    # ?p fg_wdt:P1132 fg_wd:Q960698.
    OPTIONAL {
      # ?p rdfs:label ?p_labell.
      FILTER(lang(?p_labell) IN ('en'))
    }
  }
}
ORDER BY ?p
"""
)

# %%
# print results nicely
for row in qres:
   print(row.asdict()['p_label'])
# Out:
# Unit of measurement
# Animal
# Taxon
# Work of the visual arts
# Poem
# Speech
# Journal
# Fraud
# Type of text
# Media type
# Local institution
# Type of organisation
# Visual genre
# Field of production
# Library
# Detention facility
# Social role
# Academy of Sciences (Paris)
# Living collection
# Virtual International Authority File | VIAF
# Work
# skirmish
# Military officer
# Health professional
# Health care practitioner
# Artist
# Medical organization
# Dictionary
# International Standard Identifier for Libraries and Related Organizations | ISIL
# Office in Old Regime France
# Financial office
# Religious organisation
# Periodical
# WEMI work
# Medical facility
# Ministery
# Governor
# Government agency
# Office
# Syndic
# Organisational division
# Choiseul
# Manuscript
# Sovereign court
# Revolutionnary institution (France)
# Royal commissionner
# Educational institution
# Institution of secondary education
# Architectural structure
# Real estate
# Craftsman
# Engineer
# Diocese
# Provost
# French institution
# Garden
# Musketeers of the Guard
# Cleric
# Financier
# Building trade
# King / Queen
# Infrastructure
# Public facility
# Engineer of the French Corps of Military Engineers
# Violinist
# Information carrier
# Text
# Artefact
# Print publication
# Collection
# Social status
# Cause of death
# Company
# Profession
# Type of classification
# Professor
# Pathology
# Protestantism
# Christianity
# Function
# Ruling sovereign
# Bird
# Ranking
# Romance / Novel
# Material
# Quality
# Type of work
# Type of entity
# Legal Status
# Tool
# Career statement that captures a sequence of incumbents
# Publication
# Manual trade
# Type of locality
# Type of construction
# Activity
# Privy councillor of the government
# Tradesman
# Captain
# Inspector
# Instrument maker
# Merchant
# Teacher
# Painter
# Military personel
# Music teacher
# Protestant Pastor
# Government councillor
# Psychiatric hospital
# Carpenter
# Privy councillor
# Councillor of the court
# Councillor
# Foreign Associate
# Chemist
# Manufacturer
# Abbot/Abbess
# Movie
# Physician
# Infantry captain
# Jurist
# Writing system
# General tax collector
# Procurator
# Class of FactGrid types
# Book
# Mill
# Actor/Actress
# Typography
# Ecclesiastical occupation
# Mother
# Duchy of Saxe-Gotha-Altenburg
# Gothic script
# Special purpose building
# Type of event
# Ancestor
# Crime
# Type of statement
# FactGrid Type
# Material type
# Type of pathology
# Living being
# Recognition
# Media
# Title aspect
# Theater institution
# Licensed bookseller or printer (France)
# Class of units
# Archival object
# WEMI expression
# WEMI manifestation
# WEMI item
# Creator
# Parent
# Great-grandparent
# Great-grandchild
# Grandparent
# Laborer
# Christian Church
# Classification/Taxonomy
# Treaty
# Vocabulary
# Stift
# Persecution
# Building
# Intaglio
# Monastery member with a leadership position
# Head of an (arch)diocese (HRE)
# Spiritual Counselor
# Mythical entity
# Artist (performing arts)
# Head of State
# Autobiographical text
# GOV-object type
# Locality
# City
# Combat
# Event
# Livestock
# Type of school
# Type of building
# Script
# Internment camp
# Forced labour camp
# Illegal personal violence
# Infanterie officer
# Camp
# Visual artwork
# Sculpture

# %% [markdown]
# ## TODO: classes of keywords ?
#
# ## 2.0 - Collecting Factgrid projects names etc.

# %%
FG_P = Namespace("https://database.factgrid.de/prop/")
FG_PS = Namespace("https://database.factgrid.de/prop/statement/")
g4 = Graph()
g4.bind("fg_wd", FG_WD)
g4.bind("fg_wdt", FG_WDT)
g4.bind("fg_p", FG_P)
g4.bind("fg_ps", FG_PS)
# define query for projects
qres = g4.query(
   """
SELECT ?author_labell ?project_labell ?date ?localisation_labell ?coordinates
WHERE {
    SERVICE <https://database.factgrid.de/sparql> {
# ?project fg_wdt:P2 fg_wd:Q11295.
   OPTIONAL {
      # ?project rdfs:label ?project_labell.
      FILTER(lang(?project_labell) IN ('en'))
   }
   OPTIONAL  {
      # ?project fg_wdt:P49 ?date .
   }
   OPTIONAL {
      # ?project fg_p:P297/fg_ps:P297 ?localisation .
      # ?localisation rdfs:label ?localisation_labell.
      FILTER(lang(?localisation_labell) IN ('en'))
      # ?localisation fg_wdt:P48 ?coordinates
    }
   OPTIONAL {
      # ?project fg_wdt:P21 ?author .
      # ?author rdfs:label ?author_labell
      FILTER(lang(?author_labell) IN ('en'))
          }
}
}
ORDER BY ?project
   """
)

# %% [markdown]
# ## [TOOL] Create a function to convert from SPARQLResult to Dataframe

# %%
from pandas import DataFrame
from rdflib.plugins.sparql.processor import SPARQLResult

def sparql_results_to_df(results: SPARQLResult) -> DataFrame:
    """
    Export results from an rdflib SPARQL query into a `pandas.DataFrame`,
    using Python types. See https://github.com/RDFLib/rdflib/issues/1179.
    """
    return DataFrame(
        data=([None if x is None else x.toPython() for x in row] for row in results),
        columns=[str(x) for x in results.vars],
    )

# %%
qres_df = sparql_results_to_df(qres)
qres_df
# Out:
#               author_labell  \
# 0            Florian Thiery
# 1            Florian Thiery
# 2              Lennart Gard
# 3         Christian Wirkner
# 4            Erik Liebscher
# ..                      ...
# 150                    None
# 151       Edmund Hausfelder
# 152          Marie Gunreben
# 153          Bruno Belhoste
# 154  David Riccardo Armando
#
#                                         project_labell  \
# 0                   The FactGrid Ogham Project (2024-)
# 1                   The FactGrid Ogham Project (2024-)
# 2    Lennart Gard, Group formation in Early Modern ...
# 3    Christian Wirkner, Research for the Gotha Illu...
# 4    Erik Liebscher, Gotha and the late 18th and ea...
# ..                                                 ...
# 150           DABS | German Emigrant Letter Collection
# 151  Edmund Hausfelder, The families of Adam Weisha...
# 152            Marie Gunreben 1660-1750, Novel formats
# 153           Harmonia Universalis project (2019-2023)
# 154           Harmonia Universalis project (2019-2023)
#
#                          date localisation_labell  \
# 0   2024-01-01 00:00:00+00:00     Ireland (state)
# 1   2024-01-01 00:00:00+00:00            Scotland
# 2                         NaT                None
# 3                         NaT                None
# 4   2017-01-01 00:00:00+00:00                None
# ..                        ...                 ...
# 150                       NaT                None
# 151                       NaT                None
# 152                       NaT                None
# 153                       NaT              France
# 154                       NaT              France
#
#                           coordinates
# 0    Point(-7.921111111 53.351111111)
# 1                    Point(-4.0 56.0)
# 2                                None
# 3                                None
# 4                                None
# ..                                ...
# 150                              None
# 151                              None
# 152                              None
# 153                   Point(2.0 47.0)
# 154                   Point(2.0 47.0)
#
# [155 rows x 5 columns]

# %% [markdown]
# ## 2.0 Map of location of projects (proportional circles ? heat map ?)

# %%
import geopandas as gpd

# We create a spatial dataframe with geopandas
gs = gpd.GeoSeries.from_wkt(qres_df['coordinates'])
# CRS: Coordinates Refrence System
gdf = gpd.GeoDataFrame(qres_df, geometry=gs, crs="EPSG:4326")

gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_08b42415c2d8dfbc36b0a11929f0cf08 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_08b42415c2d8dfbc36b0a11929f0cf08&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_08b42415c2d8dfbc36b0a11929f0cf08 = L.map(
#                 &quot;map_08b42415c2d8dfbc36b0a11929f0cf08&quot;,
#                 {
#                     center: [50.69375, -39.78975],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_08b42415c2d8dfbc36b0a11929f0cf08);
#
#
#
#
#
#             var tile_layer_a9cee54781c879e844d7cb55d88256ab = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a9cee54781c879e844d7cb55d88256ab.addTo(map_08b42415c2d8dfbc36b0a11929f0cf08);
#
#
#             map_08b42415c2d8dfbc36b0a11929f0cf08.fitBounds(
#                 [[39.0, -98.5795], [62.3875, 19.0]],
#                 {}
#             );
#
#
#         function geo_json_4031b83fcd32b82ae738a862b103243d_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_4031b83fcd32b82ae738a862b103243d_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_4031b83fcd32b82ae738a862b103243d_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_4031b83fcd32b82ae738a862b103243d_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_4031b83fcd32b82ae738a862b103243d_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_4031b83fcd32b82ae738a862b103243d.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_4031b83fcd32b82ae738a862b103243d_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_4031b83fcd32b82ae738a862b103243d = L.geoJson(null, {
#                 onEachFeature: geo_json_4031b83fcd32b82ae738a862b103243d_onEachFeature,
#
#                 style: geo_json_4031b83fcd32b82ae738a862b103243d_styler,
#                 pointToLayer: geo_json_4031b83fcd32b82ae738a862b103243d_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_4031b83fcd32b82ae738a862b103243d_add (data) {
#             geo_json_4031b83fcd32b82ae738a862b103243d
#                 .addData(data);
#         }
#             geo_json_4031b83fcd32b82ae738a862b103243d_add({&quot;bbox&quot;: [-98.5795, 39.0, 19.0, 62.3875], &quot;features&quot;: [{&quot;bbox&quot;: [-7.921111111, 53.351111111, -7.921111111, 53.351111111], &quot;geometry&quot;: {&quot;coordinates&quot;: [-7.921111111, 53.351111111], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;author_labell&quot;: &quot;Florian Thiery&quot;, &quot;coordinates&quot;: &quot;Point(-7.921111111 53.351111111)&quot;, &quot;date&quot;: &quot;2024-01-01 00:00:00+00:00&quot;, &quot;localisation_labell&quot;: &quot;Ireland (state)&quot;, &quot;project_labell&quot;: &quot;The FactGrid Ogham Project (2024-)&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-4.0, 56.0, -4.0, 56.0], &quot;geometry&quot;: {&quot;coordinates

# %% [markdown]
# ## 2.1 Querying the number of statements per projects

# %%
FG_WIKIBASE = Namespace("http://wikiba.se/ontology#")
g5 = Graph()
g5.bind("fg_wd", FG_WD)
g5.bind("fg_wdt", FG_WDT)
g5.bind("fg_wikibase", FG_WIKIBASE)
# define query for projects
qres = g5.query(
   """
SELECT ?project_labell ?date ?stmtcount
WHERE {
    SERVICE <https://database.factgrid.de/sparql> {
        # ?project fg_wdt:P2 fg_wd:Q11295 .
	# ?project fg_wdt:P49 ?date .
	# ?project fg_wikibase:statements ?stmtcount .
      	# ?project rdfs:label ?project_labell.
      	FILTER(lang(?project_labell) IN ('en'))
   }
}
ORDER BY DESC (?stmtcount)
LIMIT 100
   """
)

# %%
sparql_results_to_df(qres)
# Out:
#                                        project_labell  \
# 0   Landscape of Education and Culture of Knowledg...
# 1     BETA / Bibliografía Española de Textos Antiguos
# 2                                         PhiloBiblon
# 3              The FactGrid Cuneiform Project (2021–)
# 4   Heino Richard, Raw data for Thuringian genealo...
# 5   Paul Fröhlich/ Frank Hüther, German Officers D...
# 6                  Germania Sacra in FactGrid (2020–)
# 7   David Löblich, Halle's Landscapes of Education...
# 8   Markus Meumann/ Olaf Simons, DFG project Illum...
# 9   Richard Heidler (et al.), GEPRIS Historisch: V...
# 10  Katharina Brunner, Remove NA: A LGBTIQ*-Knowle...
# 11    David Löblich, Aschersleben in FactGrid (2023-)
# 12  Isabel Heide/ Martin Gollasch/ Alexander Amin,...
# 13  David Löblich, Free Tables at the Francke Foun...
# 14            Lübeck Citizens' Testaments (2022-2023)
# 15  Marie Gunreben, The German 'Novel' around 1700...
# 16                 The FactGrid Ogham Project (2024-)
# 17                     Digital Edition of Haft Tappeh
# 18  Torsten Veit, Wessobrunns in the Baltic Sea Re...
# 19  Wolfgang Woelk, The History of Gotha's St. Joh...
# 20  Marco Heiles, A Wikibase Data Model for Manusc...
# 21  Isabella Schwaderer, Research on the Schopenha...
# 22  Katharina Waldner/ Aaron French, Research on W...
# 23  Klaus Falk, Strength and composition of the im...
# 24  Erik Liebscher, Gotha and the late 18th and ea...
# 25      Bruno Belhoste, Paris to Download (2021–2024)
# 26  Olaf Simons, Research for 'Marteau's Europe' (...
# 27  David Löblich: Waisenhauskataster des Archivs ...
# 28  Kateryna Pasichnyk, Podolian Medical Landscape...
# 29  Andreas Önnerfors, Research on 18th-century Sw...
# 30  Olaf Simons, Bertelsmann im Dritten Reich (199...
# 31  Daniel Haas, The Institutum Judaicum et Muhamm...
# 32  Jonathan Groß, Roscher’s Lexicon of Mythology ...
# 33  Sven Jaros, Making states with history. Histor...
# 34  Katrin Ott, Research on Erfurt's Amploniana li...
# 35     Rolf Keil, Research on Early Freemasonry, 2022
# 36  Research project in Breton-language literature...
# 37  Rüdiger Koch, performances Papiertheater Invis...
# 38  David Löblich, Database of Pastors in the Balt...
# 39  Tobias Christ, Research Project "Organisationa...
# 40  Anna-Maria Hünnes, Research on Scientific Netw...
# 41  Christos Varvantakis, History of Ethnographic ...
#
#                         date  stmtcount
# 0  2014-01-01 00:00:00+00:00         22
# 1  1997-01-01 00:00:00+00:00         20
# 2  1997-01-01 00:00:00+00:00         19
# 3  2021-01-01 00:00:00+00:00         16
# 4  2019-01-09 00:00:00+00:00         14
# 5  2024-02-22 00:00:00+00:00         13
# 6  2020-01-01 00:00:00+00:00         13
# 7  2023-01-01 00:00:00+00:00         13
# 8  2013-01-01 00:00:00+00:00         13
# 9  2023-01-01 00:00:00+00:00         12
# 10 2022-01-01 00:00:00+00:00         12
# 11 2023-01-01 00:00:00+00:00         11
# 12 2024-03-25 00:00:00+00:00         10
# 13 2023-01-01 00:00:00+00:00         10
# 14 2022-01-01 00:00:00+00:00         10
# 15 2020-01-01 00:00:00+00:00         10
# 16 2024-01-01 00:00:00+00:00          9
# 17 2019-01-01 00:00:00+00:00          9
# 18 2023-01-01 00:00:00+00:00          9
# 19 2022-01-01 00:00:00+00:00          9
# 20 2020-01-01 00:00:00+00:00          9
# 21 2021-01-01 00:00:00+00:00          9
# 22 2021-03-01 00:00:00+00:00          9
# 23 2023-09-15 00:00:00+00:00          8
# 24 2017-01-01 00:00:00+00:00          8
# 25 2021-01-01 00:00:00+00:00          8
# 26 1993-01-01 00:00:00+00:00          8
# 27 2025-01-14 00:00:00+00:00          7
# 28 2023-01-01 00:00:00+00:00          7
# 29 2020-01-01 00:00:00+00:00          7
# 30 1999-01-07 00:00:00+00:00          7
# 31 2025-01-01 00:00:00+00:00          6
# 32 2023-11-19 00:00:00+00:00          6
# 33 2023-01-01 00:00:00+00:00          6
# 34 2020-09-18 00:00:00+00:00          6
# 35 2022-01-01 00:00:00+00:00          6
# 36 2012-01-01 00:00:00+00:00          6
# 37 2023-01-01 00:00:00+00:00          6
# 38 2024-01-01 00:00:00+00:00          5
# 39 2022-01-01 00:00:00+00:00          5
# 40 2019-01-01 00:00:00+00:00          5
# 41 2023-01-01 00:00:00+00:00          5

# %% [markdown]
# ## Build query for project as domain and as range

# %%
g8 = Graph()
g8.bind("fg_wd", FG_WD)
g8.bind("fg_wikibase", FG_WIKIBASE)
# define query for projects
qres = g8.query(
   """
SELECT ?s ?wd ?o
WHERE {
  SERVICE <https://database.factgrid.de/sparql> {
    {
	  BIND (fg_wd:Q467586 as ?s)
	  # ?s ?p ?o.
	  # ?wd fg_wikibase:claim ?p.
	}
	UNION
    {
	  BIND (fg_wd:Q467586 as ?o)
	  # ?s ?p ?o.
	  # ?wd fg_wikibase:claim ?p .
	}
}}
"""
)

# Due of rdflib's limitation
for row in qres:
    g8.add(row)

print(g8.serialize(format='n3'))
# Out:
# @prefix fg_wd: <https://database.factgrid.de/entity/> .
#
# fg_wd:Q467586 fg_wd:P14 <https://database.factgrid.de/entity/statement/Q467586-a04911a4-4e6b-2f77-3a8f-643a03feb807>,
#         <https://database.factgrid.de/entity/statement/Q467586-bc64eb72-4b8e-feea-de3c-d7411d944dac>,
#         <https://database.factgrid.de/entity/statement/Q467586-ec3de53d-4cd9-f18d-1a65-d723b72155eb> ;
#     fg_wd:P146 <https://database.factgrid.de/entity/statement/Q467586-1109ef60-4770-bcf6-273f-e35081034ed8>,
#         <https://database.factgrid.de/entity/statement/Q467586-2d313b59-40aa-cd4e-8bf1-360f368c6d1b>,
#         <https://database.factgrid.de/entity/statement/Q467586-4429fb17-4159-8ffb-7d71-0502885ad9a2> ;
#     fg_wd:P178 <https://database.factgrid.de/entity/statement/Q467586-50b16fff-4dcf-5606-b522-d31b3171397f>,
#         <https://database.factgrid.de/entity/statement/Q467586-78690e6a-406f-8a16-874b-7b6acb3a1f2f>,
#         <https://database.factgrid.de/entity/statement/Q467586-7aa62eef-46cc-b1ee-df22-fbcd78eaed41>,
#         <https://database.factgrid.de/entity/statement/Q467586-aba12a16-408b-ff07-58f5-4524ab7751b6> ;
#     fg_wd:P2 <https://database.factgrid.de/entity/statement/Q467586-ca8c4fa0-4cd6-2942-4fcb-5dd09fd19481> ;
#     fg_wd:P243 <https://database.factgrid.de/entity/statement/Q467586-755fd7d0-4ba1-68c2-0a17-f83df1f95c11>,
#         <https://database.factgrid.de/entity/statement/Q467586-90c50881-4e2f-5dfd-bc35-e499c8e0c15f>,
#         <https://database.factgrid.de/entity/statement/Q467586-d0dc98f4-43f3-9433-753f-2f34f5d6e6de> ;
#     fg_wd:P267 <https://database.factgrid.de/entity/statement/Q467586-4e19a2c5-4e40-0bc6-0de5-250901a6b079>,
#         <https://database.factgrid.de/entity/statement/Q467586-d03b5db2-45be-5e22-257d-63f213b6a3a2> ;
#     fg_wd:P297 <https://database.factgrid.de/entity/statement/Q467586-44DC21BE-0290-412A-A64F-A1F440C71163> ;
#     fg_wd:P309 <https://database.factgrid.de/entity/statement/Q467586-fb7705e4-453f-5530-d081-aedd9f97c980> ;
#     fg_wd:P319 <https://database.factgrid.de/entity/statement/Q467586-c4dbc146-4bbf-65f4-87d9-1b1fc68bebf6> ;
#     fg_wd:P49 <https://database.factgrid.de/entity/statement/Q467586-ad0f2ae3-4a98-e0f1-5170-2b7962986ce0> ;
#     fg_wd:P50 <https://database.factgrid.de/entity/statement/Q467586-9a410bba-46df-7307-95e9-b6005cb9f69a> ;
#     fg_wd:P67 <https://database.factgrid.de/entity/statement/Q467586-8ecb45f9-4bf0-4860-16dd-8b6116a72dc5> .

# %% [markdown]
# ## Draw resulting graph

# %%
from rdflib.extras.external_graph_libs import rdflib_to_networkx_graph
import networkx as nx
import matplotlib.pyplot as plt

ug8 = rdflib_to_networkx_graph(g8)
nx.draw(ug8)

# %% [markdown]
# We can also use the ipysigma library, for displaing an interactive graph (but its work only in an interactive jupyter session)

# %%
from ipysigma import Sigma
Sigma(ug8)
# Out:
# Sigma(nx.Graph with 23 nodes and 22 edges)

# %% [markdown]
# ## 2.2 Querying for the list of statements for a given project
#
# A view of the graph's depth at the level of a project description.

# %%
g6 = Graph()
g6.bind("fg_wd", FG_WD)
g6.bind("fg_wikibase", FG_WIKIBASE)
# define query for statements of a choosen project
qres = g6.query(
   """
SELECT ?project ?wd_labell ?ps_ ?ps_labell ?wdpq ?wdpq_labell ?pq_ ?pq_labell
WHERE {
    SERVICE <https://database.factgrid.de/sparql> {
  VALUES (?project) {(fg_wd:Q467586)}

  # ?project ?p ?statement .
  # ?statement ?ps ?ps_ .
  OPTIONAL { ?ps_ rdfs:label ?ps_labell.
  FILTER(lang(?ps_labell) IN ('en'))}
  # ?wd fg_wikibase:claim ?p .
  # ?wd fg_wikibase:statementProperty ?ps .
  OPTIONAL {?wd rdfs:label ?wd_labell.
  FILTER(lang(?wd_labell) IN ('en'))}

  OPTIONAL {
  # ?statement ?pq ?pq_ .
  # ?wdpq fg_wikibase:qualifier ?pq .
  # ?wdpq rdfs:label ?wdpq_labell.
  FILTER(lang(?wdpq_labell) IN ('en'))
  # ?pq_ rdfs:label ?pq_labell.
  FILTER(lang(?pq_labell) IN ('en'))
  }
  }
}
 ORDER BY ?wd ?ps_
   """
)

# %%
sparql_results_to_df(qres)
# Out:
#                                         project  \
# 0   https://database.factgrid.de/entity/Q467586
# 1   https://database.factgrid.de/entity/Q467586
# 2   https://database.factgrid.de/entity/Q467586
# 3   https://database.factgrid.de/entity/Q467586
# 4   https://database.factgrid.de/entity/Q467586
# 5   https://database.factgrid.de/entity/Q467586
# 6   https://database.factgrid.de/entity/Q467586
# 7   https://database.factgrid.de/entity/Q467586
# 8   https://database.factgrid.de/entity/Q467586
# 9   https://database.factgrid.de/entity/Q467586
# 10  https://database.factgrid.de/entity/Q467586
# 11  https://database.factgrid.de/entity/Q467586
# 12  https://database.factgrid.de/entity/Q467586
# 13  https://database.factgrid.de/entity/Q467586
# 14  https://database.factgrid.de/entity/Q467586
# 15  https://database.factgrid.de/entity/Q467586
# 16  https://database.factgrid.de/entity/Q467586
# 17  https://database.factgrid.de/entity/Q467586
# 18  https://database.factgrid.de/entity/Q467586
# 19  https://database.factgrid.de/entity/Q467586
# 20  https://database.factgrid.de/entity/Q467586
# 21  https://database.factgrid.de/entity/Q467586
#
#                         wd_labell  \
# 0             In leading position
# 1             In leading position
# 2             In leading position
# 3              Online information
# 4              Online information
# 5              Online information
# 6   Executing Individuals / staff
# 7   Executing Individuals / staff
# 8   Executing Individuals / staff
# 9   Executing Individuals / staff
# 10                    Instance of
# 11                          Topic
# 12                          Topic
# 13                          Topic
# 14         Organisational context
# 15         Organisational context
# 16       Territorial localisation
# 17     FactGrid table of contents
# 18            Parent organisation
# 19                     Begin date
# 20                       End date
# 21                    Financed by
#
#                                                 ps_  \
# 0        https://database.factgrid.de/entity/Q22239
# 1       https://database.factgrid.de/entity/Q395648
# 2       https://database.factgrid.de/entity/Q467637
# 3   https://idw-online.de/de/news?print=1&id=576230
# 4                https://studpro.hypotheses.org/463
# 5    https://www.hsozkult.de/searching/id/job-39316
# 6       https://database.factgrid.de/entity/Q467640
# 7       https://database.factgrid.de/entity/Q467717
# 8       https://database.factgrid.de/entity/Q468059
# 9       https://database.factgrid.de/entity/Q468060
# 10       https://database.factgrid.de/entity/Q11295
# 11      https://database.factgrid.de/entity/Q246098
# 12      https://database.factgrid.de/entity/Q395418
# 13       https://database.factgrid.de/entity/Q40154
# 14       https://database.factgrid.de/entity/Q11262
# 15       https://database.factgrid.de/entity/Q11264
# 16       https://database.factgrid.de/entity/Q94419
# 17                     https://tinyurl.com/2lxfgew4
# 18       https://database.factgrid.de/entity/Q11262
# 19                        2014-01-01 00:00:00+00:00
# 20                        2017-01-01 00:00:00+00:00
# 21      https://database.factgrid.de/entity/Q467636
#
#                                             ps_labell  \
# 0                                       Martin Mulsow
# 1                                      Kathrin Paasch
# 2                                   Alexander Schunka
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                    Annemarie Müller
# 7                                    Shirley Brückner
# 8                                       Thomas Töpfer
# 9                                          Jens Nagel
# 10                    FactGrid based research project
# 11                                          Education
# 12                                Early modern period
# 13                      Duchy of Saxe-Gotha-Altenburg
# 14                             Gotha Research Library
# 15  Gotha Research Centre of the University of Erfurt
# 16                  FRG | Federal Republic of Germany
# 17                                               None
# 18                             Gotha Research Library
# 19                                               None
# 20                                               None
# 21  Thuringian Ministry for Economy, Science and D...
#
#                                         wdpq      wdpq_labell  \
# 0                                       None             None
# 1                                       None             None
# 2                                       None             None
# 3                                       None             None
# 4                                       None             None
# 5                                       None             None
# 6   https://database.factgrid.de/entity/P820  Object has role
# 7   https://database.factgrid.de/entity/P820  Object has role
# 8   https://database.factgrid.de/entity/P820  Object has role
# 9   https://database.factgrid.de/entity/P820  Object has role
# 10                                      None             None
# 11                                      None             None
# 12                                      None             None
# 13                                      None             None
# 14                                      None             None
# 15                                      None             None
# 16                                      None             None
# 17                                      None             None
# 18                                      None             None
# 19                                      None             None
# 20                                      None             None
# 21                                      None             None
#
#                                             pq_           pq_labell
# 0                                          None                None
# 1                                          None                None
# 2                                          None                None
# 3                                          None                None
# 4                                          None                None
# 5                                          None                None
# 6   https://database.factgrid.de/entity/Q467641  Research Assistant
# 7   https://database.factgrid.de/entity/Q439378          Researcher
# 8   https://database.factgrid.de/entity/Q439378          Researcher
# 9   https://database.factgrid.de/entity/Q439378          Researcher
# 10                                         None                None
# 11                                         None                None
# 12                                         None                None
# 13                                         None                None
# 14                                         None                None
# 15                                         None                None
# 16                                         None                None
# 17                                         None                None
# 18                                         None                None
# 19                                         None                None
# 20                                         None                None
# 21                                         None                None

# %% [markdown]
# ## Draw resulting graph
#
# ## TODO: network of information / agents surrounding a project
#
# ## 2.3 Querying for topics of FactGrid projects

# %%
g7 = Graph()
g7.bind("fg_wd", FG_WD)
g7.bind("fg_wdt", FG_WDT)
# define query for projects
qres = g7.query(
   """
SELECT ?topic_labell ?project_labell ?date
WHERE {
    SERVICE <https://database.factgrid.de/sparql> {
        # ?project fg_wdt:P2 fg_wd:Q11295 .
	# ?project fg_wdt:P49 ?date .
	# ?project fg_wdt:P243 ?topic .
      	# ?project rdfs:label ?project_labell.
      	FILTER(lang(?project_labell) IN ('en'))
      	# ?topic rdfs:label ?topic_labell.
      	FILTER(lang(?topic_labell) IN ('en'))
   }
}
ORDER BY ?topic_labell
   """
)

# %%
sparql_results_to_df(qres)
# Out:
#                                          topic_labell  \
# 0                                        17th century
# 1                                        18th century
# 2                                            Academia
# 3                                        Aschersleben
# 4   Christian Kirchner (ed.), Das Seelenregister d...
# 5                                           Cuneiform
# 6                                           Cuneiform
# 7                       Duchy of Saxe-Gotha-Altenburg
# 8                                 Early modern period
# 9                                           Education
# 10  Ernst Wiedasch, Programm des Königlichen Pädag...
# 11                                              Exile
# 12                                Francke Foundations
# 13                                Francke Foundations
# 14    Francke Foundations Archives Orphanage Registry
# 15  Frank Heinzig (et. al.), Die Bürgerbücher der ...
# 16              Free Table of the Francke Foundations
# 17  German Reich / Greater German Reich ("Nazi Ger...
# 18  German Reich / Greater German Reich ("Nazi Ger...
# 19  Herzoglich-Sachsen-Gotha- und Altenburgischer ...
# 20                Institutum Judaicum et Muhammedicum
# 21  Karl Pabst (ed.), Verzeichnis der Schüler des ...
# 22                                               LGBT
# 23                                      Legal history
# 24  Lodge "Cosmopolit" / "Zum Rautenkranz" / "(Ern...
# 25                                   Medieval studies
# 26                                   Military history
# 27               Military history of the 20th century
# 28                                              Ogham
# 29                             Papiertheater Invisius
# 30                                      Prose fiction
# 31                                      Prosopography
# 32                                      Prosopography
# 33                                         Reichswehr
# 34                               Schopenhauer Society
# 35                                   Second World War
# 36                                   Stucco plasterer
# 37                                  Thirty Years' War
# 38  Thüringer Pfarrerbuch, vol. 1: Herzogtum Gotha...
# 39  Ulrich Lutzkat, Die Abiturienten des Gymnasium...
# 40  University of Halle / Martin Luther University...
# 41                             Wartburg Festival 1817
#
#                                        project_labell  \
# 0   Marie Gunreben, The German 'Novel' around 1700...
# 1   Marie Gunreben, The German 'Novel' around 1700...
# 2   Richard Heidler (et al.), GEPRIS Historisch: V...
# 3     David Löblich, Aschersleben in FactGrid (2023-)
# 4   Heino Richard, Raw data for Thuringian genealo...
# 5                      Digital Edition of Haft Tappeh
# 6              The FactGrid Cuneiform Project (2021–)
# 7   Landscape of Education and Culture of Knowledg...
# 8   Landscape of Education and Culture of Knowledg...
# 9   Landscape of Education and Culture of Knowledg...
# 10  Heino Richard, Raw data for Thuringian genealo...
# 11  Richard Heidler (et al.), GEPRIS Historisch: V...
# 12  David Löblich, Free Tables at the Francke Foun...
# 13  David Löblich, Halle's Landscapes of Education...
# 14  David Löblich: Waisenhauskataster des Archivs ...
# 15  Heino Richard, Raw data for Thuringian genealo...
# 16  David Löblich, Free Tables at the Francke Foun...
# 17  Paul Fröhlich/ Frank Hüther, German Officers D...
# 18  Richard Heidler (et al.), GEPRIS Historisch: V...
# 19  Heino Richard, Raw data for Thuringian genealo...
# 20  Daniel Haas, The Institutum Judaicum et Muhamm...
# 21  Heino Richard, Raw data for Thuringian genealo...
# 22  Katharina Brunner, Remove NA: A LGBTIQ*-Knowle...
# 23            Lübeck Citizens' Testaments (2022-2023)
# 24  Wolfgang Woelk, The History of Gotha's St. Joh...
# 25            Lübeck Citizens' Testaments (2022-2023)
# 26  Klaus Falk, Strength and composition of the im...
# 27  Paul Fröhlich/ Frank Hüther, German Officers D...
# 28                 The FactGrid Ogham Project (2024-)
# 29  Rüdiger Koch, performances Papiertheater Invis...
# 30  Marie Gunreben, The German 'Novel' around 1700...
# 31                     Digital Edition of Haft Tappeh
# 32             The FactGrid Cuneiform Project (2021–)
# 33  Paul Fröhlich/ Frank Hüther, German Officers D...
# 34  Isabella Schwaderer, Research on the Schopenha...
# 35  Paul Fröhlich/ Frank Hüther, German Officers D...
# 36  Torsten Veit, Wessobrunns in the Baltic Sea Re...
# 37  Klaus Falk, Strength and composition of the im...
# 38  Heino Richard, Raw data for Thuringian genealo...
# 39  Heino Richard, Raw data for Thuringian genealo...
# 40  David Löblich, Halle's Landscapes of Education...
# 41  Isabel Heide/ Martin Gollasch/ Alexander Amin,...
#
#                         date
# 0  2020-01-01 00:00:00+00:00
# 1  2020-01-01 00:00:00+00:00
# 2  2023-01-01 00:00:00+00:00
# 3  2023-01-01 00:00:00+00:00
# 4  2019-01-09 00:00:00+00:00
# 5  2019-01-01 00:00:00+00:00
# 6  2021-01-01 00:00:00+00:00
# 7  2014-01-01 00:00:00+00:00
# 8  2014-01-01 00:00:00+00:00
# 9  2014-01-01 00:00:00+00:00
# 10 2019-01-09 00:00:00+00:00
# 11 2023-01-01 00:00:00+00:00
# 12 2023-01-01 00:00:00+00:00
# 13 2023-01-01 00:00:00+00:00
# 14 2025-01-14 00:00:00+00:00
# 15 2019-01-09 00:00:00+00:00
# 16 2023-01-01 00:00:00+00:00
# 17 2024-02-22 00:00:00+00:00
# 18 2023-01-01 00:00:00+00:00
# 19 2019-01-09 00:00:00+00:00
# 20 2025-01-01 00:00:00+00:00
# 21 2019-01-09 00:00:00+00:00
# 22 2022-01-01 00:00:00+00:00
# 23 2022-01-01 00:00:00+00:00
# 24 2022-01-01 00:00:00+00:00
# 25 2022-01-01 00:00:00+00:00
# 26 2023-09-15 00:00:00+00:00
# 27 2024-02-22 00:00:00+00:00
# 28 2024-01-01 00:00:00+00:00
# 29 2023-01-01 00:00:00+00:00
# 30 2020-01-01 00:00:00+00:00
# 31 2019-01-01 00:00:00+00:00
# 32 2021-01-01 00:00:00+00:00
# 33 2024-02-22 00:00:00+00:00
# 34 2021-01-01 00:00:00+00:00
# 35 2024-02-22 00:00:00+00:00
# 36 2023-01-01 00:00:00+00:00
# 37 2023-09-15 00:00:00+00:00
# 38 2019-01-09 00:00:00+00:00
# 39 2019-01-09 00:00:00+00:00
# 40 2023-01-01 00:00:00+00:00
# 41 2024-03-25 00:00:00+00:00

# %% [markdown]
# ## Draw timeline
#
# # 3.0 Collecting sub-graph of a given project
#
# ## build query

# %%
g9 = Graph()
g9.bind("fg_wd", FG_WD)
g9.bind("fg_wikibase", FG_WIKIBASE)
# define query for projects
qres = g9.query(
   """
SELECT ?s ?wd ?o
WHERE {
  SERVICE <https://database.factgrid.de/sparql> {
    {
	  BIND (fg_wd:Q467586 as ?s)
	  # ?s ?p ?o.
	  # ?wd fg_wikibase:directClaim ?p.
	}
	UNION
    {
	  BIND (fg_wd:Q467586 as ?o)
	  # ?s ?p ?o.
	  # ?wd fg_wikibase:directClaim ?p .
	}
}}
"""
)

# Due of rdflib's limitation
import rdflib
for row in qres:
    if type(row[2]) == rdflib.term.URIRef:
        g9.add(row)

# %% [markdown]
# ## draw a network ?

# %%
ug9 = rdflib_to_networkx_graph(g9)
Sigma(ug9)
# Out:
# Sigma(nx.Graph with 1,697 nodes and 1,696 edges)

# %% [markdown]
# ## Store rdf triples

# %%
# The graph g9 is write in "my_graph.rdf" file
g9.serialize(destination="my_graph.rdf", format="xml")
# Out:
# <Graph identifier=Ne31c6915e2014afea6ac55142810d77f (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# # Creating a knowledge graph
#
# ## Create a couple of triples with Python and `rdflib`

# %%
from rdflib import Graph, Literal, RDF, URIRef
# rdflib knows about quite a few popular namespaces, like W3C ontologies, schema.org etc.
from rdflib.namespace import FOAF , XSD

# Create a Graph
g = Graph()

# Create an RDF URI node to use as the subject for multiple triples
donna = URIRef("http://example.org/donna")

# Add triples using store's add() method.
g.add((donna, RDF.type, FOAF.Person))
g.add((donna, FOAF.nick, Literal("donna", lang="en")))
g.add((donna, FOAF.name, Literal("Donna Fales")))
g.add((donna, FOAF.mbox, URIRef("mailto:donna@example.org")))

# Add another person
ed = URIRef("http://example.org/edward")

# Add triples using store's add() method.
g.add((ed, RDF.type, FOAF.Person))
g.add((ed, FOAF.nick, Literal("ed", datatype=XSD.string)))
g.add((ed, FOAF.name, Literal("Edward Scissorhands")))
g.add((ed, FOAF.mbox, Literal("e.scissorhands@example.org", datatype=XSD.anyURI)))

# Bind the FOAF namespace to a prefix for more readable output
g.bind("foaf", FOAF)

# %% [markdown]
# ## Representations of the knowledge graph
#
# ### In the `n3` serialization format

# %%
# print all the data in the Notation3 format
print(g.serialize(format='n3'))
# Out:
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <http://example.org/donna> a foaf:Person ;
#     foaf:mbox <mailto:donna@example.org> ;
#     foaf:name "Donna Fales" ;
#     foaf:nick "donna"@en .
#
# <http://example.org/edward> a foaf:Person ;
#     foaf:mbox "e.scissorhands@example.org"^^xsd:anyURI ;
#     foaf:name "Edward Scissorhands" ;
#     foaf:nick "ed"^^xsd:string .

# %% [markdown]
# ### As a network graph

# %%
from rdflib.extras.external_graph_libs import rdflib_to_networkx_graph
import networkx as nx
import matplotlib.pyplot as plt

ug = rdflib_to_networkx_graph(g)
nx.draw(ug)

# %% [markdown]
# # Session information

# %%
import session_info
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# folium              0.19.5
# geopandas           1.1.1
# ipykernel           6.29.5
# ipysigma            0.24.6
# ipywidgets          7.8.1
# matplotlib          3.9.2
# networkx            3.3
# numpy               1.26.4
# pandas              2.2.2
# rdflib              7.4.0
# session_info        v1.0.1
# xarray              2023.6.0
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# CoreFoundation              NA
# Foundation                  NA
# PIL                         10.4.0
# PyObjCTools                 NA
# anyio                       NA
# appnope                     0.1.4
# arrow                       1.2.3
# astroid                     2.14.2
# asttokens                   NA
# attr                        23.2.0
# attrs                       23.2.0
# babel                       2.11.0
# bottleneck                  1.3.7
# branca                      0.8.1
# brotli                      1.0.9
# certifi                     2024.08.30
# cffi                        1.17.1
# chardet                     4.0.0
# charset_normalizer          3.3.2
# cloudpickle                 3.0.0
# colorama                    0.4.6
# comm                        0.2.2
# cycler                      0.10.0
# cython_runtime              NA
# cytoolz                     0.12.2
# dask                        2024.8.2
# dateutil                    2.9.0.post0
# debugpy                     1.8.13
# decorator                   5.2.1
# defusedxml                  0.7.1
# django                      5.2.3
# executing                   2.2.0
# fastjsonschema              NA
# fqdn                        NA
# google                      NA
# idna                        3.7
# igraph                      1.0.0
# ipython_genutils            0.2.0
# isoduration                 NA
# jedi                        0.19.2
# jinja2                      3.1.4
# joblib                      1.4.2
# json5                       NA
# jsonpointer                 2.1
# jsonschema                  4.23.0
# jsonschema_specifications   NA
# jupyter_events              0.10.0
# jupyter_server              2.14.1
# jupyterlab_server           2.27.3
# kiwisolver                  1.4.4
# lazy_object_proxy           1.10.0
# llvmlite                    0.43.0
# lz4                         4.3.2
# mapclassify                 2.10.0
# markupsafe                  2.1.3
# matplotlib_inline           0.1.7
# mpl_toolkits                NA
# nbformat                    5.10.4
# numba                       0.60.0
# numexpr                     2.8.7
# objc                        10.1
# overrides                   NA
# packaging                   24.2
# parso                       0.8.4
# platformdirs                4.3.6
# plotly                      5.24.1
# prometheus_client           NA
# prompt_toolkit              3.0.50
# psutil                      7.0.0
# pure_eval                   0.2.3
# pyarrow                     16.1.0
# pycparser                   2.21
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      3.2.3
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.19.1
# pyparsing                   3.1.2
# pyproj                      3.7.2
# pythonjsonlogger            NA
# pytz                        2024.1
# referencing                 NA
# requests                    2.32.3
# rfc3339_validator           0.1.4
# rfc3986_validator           0.1.1
# rpds                        NA
# scipy                       1.13.1
# send2trash                  NA
# shapely                     2.1.2
# six                         1.17.0
# sklearn                     1.5.1
# sniffio                     1.3.0
# socks                       1.7.1
# sphinxcontrib               NA
# stack_data                  0.6.3
# tblib                       1.7.0
# texttable                   1.7.0
# threadpoolctl               3.5.0
# tlz                         0.12.2
# toolz                       0.12.0
# tornado                     6.4.2
# traitlets                   5.14.3
# uri_template                NA
# urllib3                     2.2.3
# wcwidth                     0.2.13
# webcolors                   NA
# websocket                   1.8.0
# wrapt                       1.14.1
# xyzservices                 2022.9.0
# yaml                        6.0.2
# zmq                         26.2.1
# zope                        NA
# zstandard                   0.23.0
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             9.0.1
# jupyter_client      8.6.3
# jupyter_core        5.7.2
# jupyterlab          4.2.5
# notebook            7.2.2
# -----
# Python 3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 08:22:19) [Clang 14.0.6 ]
# macOS-14.3-arm64-arm-64bit
# -----
# Session information updated at 2025-12-09 07:53
# </pre>
# </details>

# %% [markdown]
# # APPENDICES - Figures with `plotly.graph_objects`

# %%
import plotly.graph_objects as go
import numpy as np

# Create figure
fig = go.Figure()

# Add traces, one for each slider step
for step in np.arange(0, 5, 0.1):
    fig.add_trace(
        go.Scatter(
            visible=False,
            line=dict(color="#00CED1", width=6),
            name="𝜈 = " + str(step),
            x=np.arange(0, 10, 0.01),
            y=np.sin(step * np.arange(0, 10, 0.01))))

# Make 10th trace visible
fig.data[10].visible = True

# Create and add slider
steps = []
for i in range(len(fig.data)):
    step = dict(
        method="update",
        args=[{"visible": [False] * len(fig.data)},
              {"title": "Slider switched to step: " + str(i)}],  # layout attribute
    )
    step["args"][0]["visible"][i] = True  # Toggle i'th trace to "visible"
    steps.append(step)

sliders = [dict(
    active=10,
    currentvalue={"prefix": "Frequency: "},
    pad={"t": 50},
    steps=steps
)]

fig.update_layout(
    sliders=sliders
)

fig.show()
